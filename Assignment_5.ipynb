# %% [markdown]
# 1. Sales Data Analysis Dashboard

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * The dashboard shows that a few products generate the highest revenue, with Canon EOS R5 Camera and LG OLED TV leading in total sales.
#
# * North America contributes the largest share of revenue (around 45%), followed by Asia and Europe.
#
# * The total revenue from all sales is approximately 80.57K.
#
# * Using the category and region slicers allows users to easily analyze sales trends across different product categories and geographic regions.

# %% [markdown]
# 2. Fraud Detection Analysis

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Insight 1:
#
# Fraudulent transactions are extremely low compared to non-fraud transactions, showing a highly imbalanced dataset.
#
# * Insight 2:
#
# Fraud transactions often involve higher transaction amounts, indicating suspicious large-value activity.
#
# * Insight 3:
#
# Using the slicer, filtering fraud transactions reveals patterns that are otherwise hidden in overall data.
